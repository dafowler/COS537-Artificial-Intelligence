# %% [markdown]
# <a href="https://colab.research.google.com/github/dafowler/COS495_F20_ThorobredTutoring/blob/master/DavidFowlerLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import itertools

# %% [markdown]
# This data set from https://raw.githubusercontent.com/fivethirtyeight/data/master/bad-drivers/bad-drivers.csv will give us the data related to the number of bad drivers by state, and whether they are impaired or not, and if the accidents were fatal or not, by state and how much is lost from insurance.

# %%
#open data file and store into PANDA
df=pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/bad-drivers/bad-drivers.csv")
df
# Out:
#                    State  \
# 0                Alabama
# 1                 Alaska
# 2                Arizona
# 3               Arkansas
# 4             California
# 5               Colorado
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                 Idaho
# 13              Illinois
# 14               Indiana
# 15                  Iowa
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19                 Maine
# 20              Maryland
# 21         Massachusetts
# 22              Michigan
# 23             Minnesota
# 24           Mississippi
# 25              Missouri
# 26               Montana
# 27              Nebraska
# 28                Nevada
# 29         New Hampshire
# 30            New Jersey
# 31            New Mexico
# 32              New York
# 33        North Carolina
# 34          North Dakota
# ...

# %%
df.head(18)

# %%
list(set(df.State))
# Out:
# ['North Dakota',
#  'Arkansas',
#  'Maryland',
#  'South Dakota',
#  'Wyoming',
#  'Kentucky',
#  'Arizona',
#  'Utah',
#  'Connecticut',
#  'New York',
#  'Tennessee',
#  'Rhode Island',
#  'Colorado',
#  'Louisiana',
#  'Idaho',
#  'Oregon',
#  'Massachusetts',
#  'Hawaii',
#  'Vermont',
#  'Alaska',
#  'Washington',
#  'New Mexico',
#  'South Carolina',
#  'Mississippi',
#  'Indiana',
#  'Oklahoma',
#  'Pennsylvania',
#  'Kansas',
#  'Montana',
#  'New Jersey',
#  'Georgia',
#  'Maine',
#  'Delaware',
#  'West Virginia',
#  'North Carolina',
#  'New Hampshire',
#  'Alabama',
#  'Wisconsin',
#  'Missouri',
#  'Nebraska',
#  'Michigan',
#  'Nevada',
#  'Minnesota',
#  'California',
#  'District of Columbia',
#  'Florida',
#  'Iowa',
#  'Illinois',
#  'Texas',
#  'Virginia',
#  'Ohio']

# %%
df.describe()
# Out:
#        Number of drivers involved in fatal collisions per billion miles  \
# count                                          51.000000
# mean                                           15.790196
# std                                             4.122002
# min                                             5.900000
# 25%                                            12.750000
# 50%                                            15.600000
# 75%                                            18.500000
# max                                            23.900000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# count                                          51.000000
# mean                                           31.725490
# std                                             9.633438
# min                                            13.000000
# 25%                                            23.000000
# 50%                                            34.000000
# ...

# %%
df.groupby(['State']).describe()

# %% [markdown]
# This is a box plot of the drivers per state involved in fatal collisions due to speeding.

# %%
df[['State','Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding']].boxplot(by="State",figsize=(10, 50))

# %% [markdown]
# This is a histogram plot shows the distribution of all the fatal collisions due to alcohol intoxication.

# %%
ax = df['Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired'].plot.hist(figsize=(25, 50))

# %% [markdown]
# This is a table of the states that had Car Premiums over $1000

# %%
df[(df['Car Insurance Premiums ($)']>1000)]
# Out:
#                    State  \
# 1                 Alaska
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 9                Florida
# 18             Louisiana
# 20              Maryland
# 21         Massachusetts
# 22              Michigan
# 28                Nevada
# 30            New Jersey
# 32              New York
# 39          Rhode Island
# 43                 Texas
#
#     Number of drivers involved in fatal collisions per billion miles  \
# 1                                                18.1
# 6                                                10.8
# 7                                                16.2
# 8                                                 5.9
# 9                                                17.9
# 18                                               20.5
# 20                                               12.5
# 21                                                8.2
# 22                                               14.1
# ...

# %% [markdown]
# Question 1:
# Which state had the highest percentage of speeding collisions being fatal?
# Hawaii with 54%
#
# Question 2: Does Kentucky have a Car Insurance Premium over $1000?
#   No
#
# Question 3: What is the approxiimate outlier in the alcohol impaired collisoin distribution?
# 17-23
